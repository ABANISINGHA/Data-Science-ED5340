# %% [markdown]
# # 5. WAP to implement a class called "Bank_Account" representing a person's bank account.
# The class should have the following attributes: account_holder_name (str), account_number(int), address (str) and balance (float).
# The class should have methods to implement the following:
#     deposit - Deposits a given amount into the account,
#     withdraw - Withdraws a given amount from the account,
#     check_balance - To get the current balance,
#     update_details - To update the name and address from the user and displays a message indicating successful update,
#     display_details - To display the details of the account.

# %%
class Bank_Account:
    def __init__(self,name,account_number,address,balance=0.00):
        self.account_holder_name = name
        self.account_number = account_number
        self.address  = address
        self.balance = balance
    
    def deposit(self,x):
        if x>=0:
            self.balance = self.balance + x
        else:
            print("Deposite cannot be negative amount")
        
    def withdraw(self,x):
        if self.balance>=x:
            self.balance = self.balance - x
        else:
            print("insuffitient balance")
    
    def check_balance(self):
        print("The current balance of the bank account is:",self.balance)
    
    def update_details(self,name,addr):
        self.account_holder_name = name
        self.address  = addr
        print("Update successful")
        print("Current name is {} and address is {}".format(self.account_holder_name,self.address))           
    
    def display_details(self):
        print("Printing the bank details:")
        print(self.account_holder_name,self.account_number,self.address,self.balance)
        
        
acc1 =  Bank_Account("Hari",133101,"Taramani,Chennai") 
acc1.display_details()
acc1.deposit(100)
acc1.display_details()
acc1.withdraw(750)
acc1.check_balance()
acc1.update_details("Hari Prashad P","Taramani,Chennai,Tamil Nadu")
acc1.display_details()
# Out:
# Printing the bank details:
# Hari 133101 Taramani,Chennai 0.0
# Printing the bank details:
# Hari 133101 Taramani,Chennai 100.0
# insuffitient balance
# The current balance of the bank account is: 100.0
# Update successful
# Current name is Hari Prashad P and address is Taramani,Chennai,Tamil Nadu
# Printing the bank details:
# Hari Prashad P 133101 Taramani,Chennai,Tamil Nadu 100.0

# %% [markdown]
# # 6.  Define a Matrix class of dimensions m X n (the values for m and n can be taken as input). Demonstrate matrix addition, subtraction, multiplication, element-by-element multiplication, scalar multiplication (use map here). Use operator overloading wherever possible. (Hint: In the constructor, use 'random' and create list of list using list comprehension. In the arguments of constructor, send the number of rows and columns)
# Ensure that your implementation follows best practices for class design and encapsulation in Python. Comment your code to explain the functionality of each method.

# %%
class Matrix:
    def __init__(self,rows,cols):
        self.rows = rows
        self.cols = cols
        self.matrix = [[0 for _ in range(self.cols)] for _ in range(self.rows)]  # using list comprehension

    def show_matrix(self):  # function to display the matrix
        #print(self.matrix)
        for i in range(self.rows):
            for j in range(self.cols):
                print(self.matrix[i][j],end=' ') 
            print()   
    
    # function to set the entries of the matrix by user input method
    def set_matrix(self):   
        self.matrix = [[int(input("{}{} th element:".format(i+1,j+1))) for j in range(self.cols)] for i in range(self.rows)]
    
    # function to set the entries of the matrix randomly between 0 to 10
    def random_matrix(self):
        import random
        self.matrix = [[random.randint(0,10) for j in range(self.cols)] for i in range(self.rows)]
    
    # function to add matrices. Ex- Matrix A add to matrix B and store in A
    def add(self,other):
        self.matrix = [[self.matrix[i][j]+other.matrix[i][j] for j in range(self.cols)] for i in range(self.rows)]
    
    # '+' operator overloading to add matrices
    def __add__(self,other):
        M = Matrix(self.rows,self.cols)
        M.matrix = [[self.matrix[i][j]+other.matrix[i][j] for j in range(self.cols)] for i in range(self.rows)]
        return M
    
    # function to subtruct matrices. Ex- Matrix B subtruct from matrix A and store in A 
    def sub(self,other):
        self.matrix = [[self.matrix[i][j]-other.matrix[i][j] for j in range(self.cols)] for i in range(self.rows)]
    
    # '-' operator overloading to add matrices
    def __sub__(self,other):
        M = Matrix(self.rows,self.cols)
        M.matrix = [[self.matrix[i][j]-other.matrix[i][j] for j in range(self.cols)] for i in range(self.rows)]
        return M
    
    # function to multiplication matrices. Ex- Matrix A multiply with matrix B and store in A
    def multp(self,other):
        if self.cols == other.rows:
            for i in range(self.rows):
                for j in range(other.cols):
                    for k in range(self.rows):
                        self.matrix[i][j]=self.matrix[i][j]+self.matrix[i][k]*other.matrix[k][j]
        else:
            print("Matrix multiplication is not possible")
    
    # '*' operator overloading to multiply matrices
    def __mul__(self,other):
        if self.cols == other.rows:
            M = Matrix(self.rows,other.cols)
            for i in range(self.rows):
                for j in range(other.cols):
                    for k in range(self.rows):
                        M.matrix[i][j]=M.matrix[i][j]+self.matrix[i][k]*other.matrix[k][j]
            return M 
        else:
            print("Matrix multiplication is not possible")
     
    # function to multiply matrices element by element
    def multipl_elem_by_elem(self,other):
        if self.rows==other.rows and self.cols==other.cols:
            self.matrix = [[self.matrix[i][j]*other.matrix[i][j] for j in range(self.cols)] for i in range(self.rows)]
            
        else:
            print("Matrix multiplication element by element is not possible")
    
    # function for scalar matrix multiplication, 1st map mapping with every lists inside the list and 2nd map mapping with elements of the list
    def scalar_matrix_prod(self,s):
        self.matrix = list(map(lambda row: list(map(lambda x: x * s, row)), self.matrix))

# Objects    
        
m1 = Matrix(2,2)
m2 = Matrix(2,2)
m3 = Matrix(2,2)
m4 = Matrix(2,2)
a = Matrix(2,2)
b = Matrix(2,2)
c = Matrix(2,2)
print("Default matrix:")
m1.show_matrix()
#m1.set_matrix()
#m2.set_matrix()
m1.random_matrix()
m2.random_matrix()
m3.random_matrix()

print("1st matrix:")
m1.show_matrix()
print("2nd matrix:")
m2.show_matrix()
print("3rd matrix:")
m3.show_matrix()
print("Addition of 1st and 2nd matrices by add function:")
m1.add(m2)
m1.show_matrix()
print("Addition of 2nd and 3rd matrices by operator'+':")
a = m2 + m3
a.show_matrix()
print("Subtruction of 3rd matrix from 2nd matrix by operator'-':")
c = m2 - m3
c.show_matrix()
print("Multiplication of 2nd and 3rd matrices by multiply function:")
b = m2 * m3
b.show_matrix()
print("Scalar matrix product 2nd matrix with a scalar:")
m2.scalar_matrix_prod(2)
m2.show_matrix()
print("Matrix matrix element wise product of 3rd matrix with 3rd matrix:")
m3.multipl_elem_by_elem(m3)
m3.show_matrix()
# Out:
# Default matrix:
# 0 0
# 0 0
# 1st matrix:
# 4 6
# 10 6
# 2nd matrix:
# 0 6
# 5 8
# 3rd matrix:
# 7 3
# 10 10
# Addition of 1st and 2nd matrices by add function:
# 4 12
# 15 14
# Addition of 2nd and 3rd matrices by operator'+':
# 7 9
# 15 18
# Subtruction of 3rd matrix from 2nd matrix by operator'-':
# -7 3
# -5 -2
# Multiplication of 2nd and 3rd matrices by multiply function:
# 60 60
# 115 95
# Scalar matrix product 2nd matrix with a scalar:
# 0 12
# 10 16
# Matrix matrix element wise product of 3rd matrix with 3rd matrix:
# 49 9
# 100 100

# %% [markdown]
# ##

# %% [markdown]
# # 7. Create a Python class named Time that represents a moment of time. The class should have attributes hour, minute, and second. Include the following features:
#     A constructor that initializes hour, minute, and second, with validation to ensure each attribute is within its correct range (hours: 0-23, minutes: 0-59, seconds: 0-59).
#     A __str__() method that returns the time in a format hh:mm:ss.
#     Methods set_time(hour, minute, second) and get_time() to update and access the time, respectively.
#     An add_seconds(seconds) method that adds a given number of seconds to the current time object, adjusting the hour, minute, and second attributes accordingly.

# %%
class Time:
    def __init__(self,hour = 0,minute = 0,second = 0):
        self.set_time(hour, minute, second)
    
    def set_time(self, hour, minute, second):
        if 0 <= hour < 24 and 0 <= minute < 60 and 0 <= second < 60:
            self.hour = hour
            self.minute = minute
            self.second = second
        else:
            print("Invalid time")
    def get_time(self):
        print(self.hour,self.minute,self.second)
    def __str__(self):
        return (f"{self.hour:2d}:{self.minute:2d}:{self.second:2d}")
    
    def add_second(self,second):
        s = self.second
        self.second = (self.second+second)%60
        m = self.minute
        self.minute = (self.minute + (s+second)//60)%60
        self.hour = self.hour + (m + (s+second)//60)//60
        
        
t1 = Time(2,55,50)
print("The time is:",t1) 
second = 1439
t1.add_second(second) 
print(f"After adding {second} second new time is: {t1}  ")
# Out:
# The time is:  2:55:50
# After adding 1439 second new time is:  3:19:49

# %% [markdown]
# # 8.  Create a class named Geometry that provides static methods for various geometric calculations, such as area and perimeter, for different shapes (circle, rectangle, square). Include:
# Static methods like circle_area(radius), rectangle_area(length, width), and square_area(side).
# Static methods for perimeter calculations for the above shapes.
# Ensure that methods check for valid inputs (e.g., positive numbers).

# %%
import math

class Geometry:
    @staticmethod
    def circle_area(radius):
        if radius <= 0:
            return "Not found, radius must be a positive number "
        else:
            return math.pi * radius ** 2

    @staticmethod
    def rectangle_area(length, width):
        if length <= 0 or width <= 0:
            return "Not found, length and width must be a positive number "
        else:
            return length * width

    @staticmethod
    def square_area(side):
        if side <= 0:
            return "Not found, side must be a positive number "
        else:
            return side ** 2

    @staticmethod
    def circle_perimeter(radius):
        if radius <= 0:
            return "Not found, radius must be a positive number "
        else:
            return 2 * math.pi * radius

    @staticmethod
    def rectangle_perimeter(length, width):
        if length <= 0 or width <= 0:
            return "Not found, length and width must be a positive number "
        else:
            return 2 * (length + width)

    @staticmethod
    def square_perimeter(side):
        if side <= 0:
            return "Not found, side must be a positive number "
        else:
            return 4 * side



print("Circle Area:", Geometry.circle_area(-5))
print("Rectangle Area:", Geometry.rectangle_area(4, 6))
print("Square Area:", Geometry.square_area(3))

print("Circle Perimeter:", Geometry.circle_perimeter(5))
print("Rectangle Perimeter:", Geometry.rectangle_perimeter(4, 6))
print("Square Perimeter:", Geometry.square_perimeter(3))
# Out:
# Circle Area: Not found, radius must be a positive number
# Rectangle Area: 24
# Square Area: 9
# Circle Perimeter: 31.41592653589793
# Rectangle Perimeter: 20
# Square Perimeter: 12
