# %% [markdown]
# # 1. Write a program that takes coefficients A, B, C, D, and E as inputs representing a 4th degree polynomial in the form Ax^4 + Bx^3 + Cx^2 + Dx + E. Calculate the values of this polynomial for x in the range from -100 to 100, with constant discrete intervals.
#
# Store the resulting x and y values as a NumPy array, where x represents the input values, and y represents the corresponding output values of the polynomial. Finally, use Matplotlib to plot the graph using the generated NumPy array.

# %%
import numpy as np
import matplotlib.pyplot as plt
def polynomial(x):
    A = float(input("Enter the coeffitient of x^4:"))
    B = float(input("Enter the coeffitient of x^3:"))
    C = float(input("Enter the coeffitient of x^2:"))
    D = float(input("Enter the coeffitient of x^1:"))
    E = float(input("Enter the value of the constant:"))
    print(f"The polynomial is {A}x^4 + {B}x^3+ {C}x^2 + {D}x + {E}")
    return A*(x**4)+ B*(x**3) + C*(x**2) + D*(x**1) + E
x = np.linspace(-100,100,21) 
y = polynomial(x)
plt.title('Graph of polynomial function')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.plot(x,y,color="r")
# Out:
# Enter the coeffitient of x^4:-5
# Enter the coeffitient of x^3:3
# Enter the coeffitient of x^2:6
# Enter the coeffitient of x^1:11
# Enter the value of the constant:8
# The polynomial is -5.0x^4 + 3.0x^3+ 6.0x^2 + 11.0x + 8.0

# %% [markdown]
# # 2. Suppose you have a dictionary containing information about monthly sales for different products over a period of time. The dictionary has the following structure.
#
# sales_data = {
#
#     'Product': ['A', 'B', 'A', 'C', 'B', 'C', 'A', 'B', 'C'],
#
#     'Month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar', 'Apr', 'Apr', 'Apr'],
#
#     'Sales': [100, 150, 200, 120, 180, 220, 90, 110, 130]
#
# }
#
# Write a Python script to convert this dictionary into a pandas DataFrame, calculate the total sales for each product over the entire period, and then create a bar plot using matplotlib to visualize the total sales for each product.

# %%
import pandas as pd
sales_data = {
'Product': ['A', 'B', 'A', 'C', 'B', 'C', 'A', 'B', 'C'],
'Month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar', 'Apr', 'Apr', 'Apr'],
'Sales': [100, 150, 200, 120, 180, 220, 90, 110, 130]
}

# %%
df = pd.DataFrame(sales_data, columns=['Product', 'Month','Sales' ])
df
# Out:
#   Product Month  Sales
# 0       A   Jan    100
# 1       B   Jan    150
# 2       A   Feb    200
# 3       C   Feb    120
# 4       B   Mar    180
# 5       C   Mar    220
# 6       A   Apr     90
# 7       B   Apr    110
# 8       C   Apr    130

# %%
total_Sale_df = df.groupby('Product')['Sales'].sum().reset_index()
total_Sale_df
# Out:
#   Product  Sales
# 0       A    390
# 1       B    440
# 2       C    470

# %%
total_Sale_df.plot(kind='bar')
plt.title('Total Sales by Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# # 3. Create visualizations for the following mathematical functions using Matplotlib:
#
# Plot the following single-variable functions over the range
#
# [−10,10], and include a title and labels for the axes:
#
# (1) y = cos(x)
#
# (2) y = e^x
#
# (3) y = log(x), where x>0
#
#
# Generate surface plots for these multi-variable functions over the range
#
# x=[−10,10] and y=[−10,10] , ensuring to add a title and labels for all axes:
#
# (1) z = cos(sqrt(x^2+y^2)
#
# (2) z = e^(-(x^2+y^2))
#
# (3) z =  log(x^2+y^2) where x^2+y^2>0

# %% [markdown]
# # (1) y = cos(x)

# %%
x = np.linspace(-10,10,201)
y = np.cos(x)
plt.xlabel('x')
plt.ylabel('y = cos(x)')
plt.plot(x,y)

# %% [markdown]
# # (2) y = e^x

# %%
x = np.linspace(-10,10,201)
y = np.exp(x)
plt.xlabel('x')
plt.ylabel('y = exp(x)')
plt.plot(x,y,color='b')

# %% [markdown]
# # (3) y = log(x), where x>0

# %%
x = np.linspace(-10,10,201)
y = np.log(x[x>0])
plt.xlabel('x')
plt.ylabel('y = log(x)')
plt.plot(x[x>0],y,color='r')

# %% [markdown]
# # Generate surface plots for these multi-variable functions over the range
#
# x=[−10,10] and y=[−10,10] , ensuring to add a title and labels for all axes:

# %% [markdown]
# # (1) z = cos(sqrt(x^2+y^2)

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)
X, Y = np.meshgrid(x, y)
z = np.cos(np.sqrt(X**2 + Y**2))

fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(111, projection ='3d')   
ax.plot_surface(X, Y, z)
plt.xlabel('x')
plt.ylabel('y')
ax.set_title('cos(sqrt(x^2+y^2)')
plt.show()

# %% [markdown]
# # 2) z = e^(-(x^2+y^2))

# %%
z = np.exp(-(X**2 + Y**2))

fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(111, projection ='3d')   
ax.plot_surface(X, Y, z)
plt.xlabel('x')
plt.ylabel('y')
ax.set_title('e^(-(x^2+y^2))')
plt.show()

# %% [markdown]
# # 3) z = log(x^2+y^2) where x^2+y^2>0

# %%
z = np.log(X**2 + Y**2)

fig = plt.figure(figsize = (8,6))
ax = fig.add_subplot(111, projection ='3d')   
ax.plot_surface(X, Y, z)
plt.xlabel('x')
plt.ylabel('y')
ax.set_title('log(X**2 + Y**2)')
plt.show()

# %% [markdown]
# # 4. For the function J(w) = w^2 + (54/w), implement the bracketing method (choose your own a, b, n).

# %%
def J(w):
    if w != 0:
        return w**2 + (54/w)
    else:
        print(f"Function is not exist at {w}")
    

def exhaustive_search(a, b, n):
    step =(b-a)/n
    x1=a
    x2=a+step
    x3=a+2*step
    flag=0
    while flag!= 1:
       
        if J(x1) >= J(x2) <= J(x3):
            print(f'minimum lies in [{x1},{x3}]')
            flag=1
        else:
            x1=x2
            x2=x3
            x3=x3+step
 
        if x3 >b:
            print('no minimum exists ')
            flag=1



a = 1  # lower bound of the range
b = 5  # upper bound of the range
n = 100  # number of subdivisions

exhaustive_search(a, b, n)
# Out:
# minimum lies in [2.9600000000000017,3.040000000000002]
